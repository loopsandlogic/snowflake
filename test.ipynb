# %%
from mimesis import Person
from mimesis.locales import Locale
import pandas as pd
import random

# %%
# Initialize providers

person = Person(Locale.EN)

data = []
for _ in range(100):
    emp = {
        "ID": random.randint(100, 999),
        "NAME": person.full_name(),
        "DEPARTMENT": random.choice(['HR', 'Engineering', 'Marketing', 'Sales']),
        "SALARY": round(random.uniform(60000, 150000), 2)
    }
    data.append(emp)

emp_df = pd.DataFrame(data)
print(emp_df)
# Out:
#      ID                NAME   DEPARTMENT     SALARY
# 0   136     Lavonia Carroll        Sales  132147.87
# 1   748    Frederic Bradley  Engineering   90410.90
# 2   316      Shaun Cardenas  Engineering  133729.13
# 3   571      Irish Schwartz           HR  119283.13
# 4   769  Kimbery Harrington           HR  142991.63
# ..  ...                 ...          ...        ...
# 95  623        Damien Morse  Engineering  135818.37
# 96  321     Telma Mcfarland           HR  132667.41
# 97  589          Fred Boone           HR   62478.20
# 98  780    Augustina Barber    Marketing  124619.33
# 99  739      Loren Jacobson        Sales   65505.44
#
# [100 rows x 4 columns]
